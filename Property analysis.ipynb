# %% [markdown]
# # <span style="color:SlateGray">Understanding and Cleaning the Data</span>

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv()

# List each column
for column in df.columns:
    print(column)

# %%
for column in df.columns:
    print(column)

# %%
# Define essential columns
essential_columns = [
    'Name', 'PropertyType', 'PropertySubtype', 'PropertyStatus', 'PropertyAddress', 'PropertySuiteNumber',
    'PropertyCity', 'PropertyCounty', 'PropretyState', 'PropertyZipCode', 'PropertyLatitude', 'PropertyLongitude',
    'PropertySourceURL', 'DetailsIsWetlands', 'IndustrialParkName', 'PropertyComments', 'PropertyOther',
    'PropertyDailyCarCount', 'DetailsRegion', 'PubliclyOwned', 'PropertyFrontage', 'PropertySubmarket',
    'PropertyVehiclesPerDay', 'PropertyYard', 'PropertyFloodPlain', 'PricingPricePerSqFt', 'PricingPricePerAcre',
    'PricingIsForLease', 'PricingIsForSale', 'PricingLeasePrice', 'PricingSalePrice', 'PricingLeasePriceMin',
    'PricingLeasePriceMax', 'PricingSalePriceMin', 'PricingSalePriceMax', 'PricingLeaseTerms', 'PricingSaleTerms',
    'PricingLeaseType', 'PricingSaleType', 'PricingSalePriceUnit', 'PricingIsPriceNegotiable', 'PricingInformation',
    'PricingLeaseSublease', 'BuildingSqFtMinimumAvailable', 'BuildingSqFtMaximumAvailable', 'BuildingSqFtTotal',
    'BuildingSqFtOfficeAvailable', 'BuildingTotalBuildingSqFt', 'BuildingSqFtGroundFloor', 'BuildingSqFtManufacturing',
    'BuildingSqFtWarehouse', 'BuildingCeilingHeight', 'BuildingCeilingHeightMaximum', 'BuildingCeilingHeightMinimum',
    'BuildingClearHeightRange', 'BuildingSqFtMinimumSubdivide', 'BuildingSqFtMaxContiguousSpace', 'BuildingSqFtMax',
    'BuldingSqFtTotalFloor', 'BuildingSqFtManufacturing.1', 'PropertyMaxSize', 'PropertyMinSize',
    'BuildingSprinklerSystemDescription', 'BuildingParcel', 'BuildingClass', 'BuildingConstructionStatus',
    'BuildingConstructionType', 'BuildingYearTheBuildingWasBuilt', 'BuildingYearOfLastMajorRenovation',
    'BuildingNumberOfFloors', 'BuildingNumberofParkingSpaces', 'BuildingNumberOfDriveInDocks', 'BuildingParkingRatio',
    'BuildingDatePropertyIsAvailable', 'BuildingIsMultiTenant', 'BuildingHasAirConditioning', 'BuildingIsheated',
    'BuildingHasSprinklers', 'BuildingParkingType', 'BuildingCondition', 'BuildingBusinessIndustrialPark',
    'BuildingStatus', 'BuildingIsFreeStanding', 'BuildingRoofDescription', 'BuildingNumberOfDriveInDoors',
    'BuildingNumberOfDockDoors', 'BuildingNumberOfElevatorPassengers', 'BuildingNumberOfLoadingDocks',
    'BuildingNumberOfTruckDocks', 'BuildingPriorUse', 'BuildingCurrentUse', 'BuildingPreviousTenant',
    'BuildingHasParking', 'BuildingParkingTypeDescription', 'BuildingHeatType', 'BuildingColumnSpacing',
    'BuildingConstructionDate', 'BuildingDescription', 'BuildingFloorThickness', 'BuildingFloorType',
    'BuildingHasDocks', 'BuildingHasDriveInDoors', 'BuildinghasParkingPaved', 'BuildingHasReinforcedConcreteFloor',
    'BuildingIsContiguous', 'BuildingIsExpandable', 'BuildingIsSpaceContiguous', 'BuildingName', 'BuildingOwnership',
    'BuildingSqFtExpandable', 'BuildingIsDivisible', 'BuildingIsInFloodPlain', 'BuildingCoolingSystem',
    'BuildingNumberofBuildings', 'BuildingHasCranes', 'BuildingCraneSqFtUnderHook', 'BuildingCraneCapacityTonnage',
    'BuildingFloorLoadBearingCapacity', 'BuildingOccupancyRate', 'BuildingTotalNumberOfUnits', 'TrailerSpaces',
    'BuildingNumberOfDockHighDoors', 'BuildingNumberOfGradeLevelDoors', 'BuildingSizeOfDriveInDoors',
    'BuildingCeilingEaves', 'BuildingRefrigeration', 'BuildingUnit', 'BuildingSuiteDescription', 'BuildingCamCharge',
    'BuildingCapRate', 'BuildingDockSize', 'BuildingHVAC', 'BuildingLaundry', 'BuildingLiftRoofPossible',
    'BuildingTotalBedCount', 'BuildingTotalUnits', 'BuildingNumberOfCranes', 'PropertyTotalAcres',
    'PropertyAcresMinAvailable', 'PropertyAcresMaxAvailable', 'SiteParcel', 'SiteLotSize', 'SiteMinimumSubdivide',
    'SiteAcresLargestTractAvailable', 'SitePriorUse', 'SiteSurroundingLanduseDescription', 'SiteCurrentLandUse',
    'SiteEnvironmentalAssessment', 'SiteAdditionalAcreageAvailable', 'SiteDivisible', 'SiteExpandable',
    'SiteMaximumContiguousSpace', 'SiteOwnership', 'SiteWithinCityLimits', 'SitePhase1EnvironmentalRpt', 'Topography',
    'SiteBoundarySurvey', 'SitePhase1EnvironmentalAuditDone', 'PropertyAcresAdditionalContiguousAcrestoTheProperty',
    'SiteExpandablePropertySize', 'SiteIsCompetitiveSite', 'SiteCertifiedProperty', 'SiteStatus',
    'SiteLocatedin100YearFloodPlain', 'SitePrimarySoilType', 'SiteMaxContiguousAcres', 'SiteMinContiguousAcres',
    'SiteAdjacentParcelsAvailable', 'SiteLandSplitsAvailable', 'ZoningBuilding', 'ZoningSite', 'ZoneIsInsideFedOppZone',
    'ZoneForeignTradeZone', 'BrokerCompanyName', 'BrokerContactName', 'BrokerContactEmail', 'BrokerContactCell',
    'BrokerOfficeNumber', 'ElectricServiceAvailableOnSite', 'ElectricHasElectricService', 'ElectricServiceProvider',
    'ElectricServiceProviderDistanceTo', 'ElectricServiceProviderDistanceToText', 'ElectricServiceProvider2',
    'ElectricPhase', 'ElectricAmps', 'ElectricDistributionVoltage', 'ElectricHasDualFeedAvailableFrom1Substation',
    'ElectricVoltage', 'ElectricTransmission', 'ElectricThreePhase', 'ElectricPowerType', 'SewerIsAvailableOnSite',
    'SewerService', 'SewerProvider', 'SewerProviderDistanceTo', 'SewerDistanceFromSiteFt', 'SewerSizeOfMainInches',
    'SewerTypeOfSewer', 'SewerLineSize', 'SewerAvailCapacityToProperty', 'WaterIsAvailableOnSite', 'WaterService',
    'WaterProvider', 'WaterProviderDistanceTo', 'WaterSizeOfMains', 'WaterDistanceOfMainFromSiteFt', 'WaterLineSize',
    'WaterHasOnsiteStorage', 'WaterIsOnSiteStorageElevated', 'WaterWastewater', 'WaterTankCapacity',
    'GasIsAvailableOnSite', 'GasHasService', 'GasProvider', 'GasProviderDistanceTo', 'GasLineSizeInches',
    'GasDistanceFromSiteFt', 'GasPressure', 'GasSizeOfMain', 'GasLineProviderType', 'GasIsConnected',
    'TLCIsTelecomAvailableOnsite', 'TlcFiberAvailable', 'TLCTelcomProvider', 'TLCPropertyDistanceToTelecommunicationsFt',
    'TLCFiberOptics', 'TLCNetworked', 'AirportInternationalName', 'AirportInternationalMilesDistanceTo',
    'AirportDomesticName', 'AirportDomesticMilesDistanceTo', 'AirportNearestName', 'AirportNearestDistance',
    'AirportName3', 'Airport3MilesDistanceTo', 'AirportNearestAirport', 'AirportDistancetoNearestAirport',
    'Interstate1Name', 'Interstate1MilesDistanceTo', 'Interstate2Name', 'Interstate2MilesDistanceTo',
    'Interstate3Name', 'Interstate3MilesDistanceTo', 'InterstateNearestName', 'InterstateNearestDistance',
    'USHighway1Name', 'USHighway1MilesDistanceTo', 'USHighway2Name', 'USHighway2MilesDistanceTo',
    'USHighwayNearestName', 'USHighwayNearestDistance', 'HighwayLinkageLaneType', 'HighwayLinkageDistanceTo4Lane',
    'HighwayLinkageInternalSiteAccess', 'AccessRoadName', 'AccessRoadNumberOfLanes', 'TruckRouteNearestDistance',
    'HighwayNearestHighwayName', 'HighwayNearestHighwayDistanceTo', 'InterstateNearestInterstate',
    'InterstateDistanceToNearestInterstate', 'RailServiceCarrier', 'RailMilesDistanceTo', 'RailHasAccessAvailable',
    'RailHasServiceSpur', 'RailServiceType', 'Rail1TrackStatus', 'RailAccessNearProperty', 'RailExtendedToProperty',
    'RailOnSite', 'RailNear'
]

def data_quality_score(missing_percentage):
    if missing_percentage == 0:
        return 100
    elif missing_percentage <= 2:
        return 90
    elif missing_percentage <= 5:
        return 80
    elif missing_percentage <= 10:
        return 70
    elif missing_percentage <= 20:
        return 60
    else:
        return 50

# Calculate data quality score for each property
df['DataQualityScore'] = df['MissingPercentage'].apply(data_quality_score)

# Print the data quality score for each property
print(df[['Name', 'DataQualityScore']])
# Out:
#                                    Name  DataQualityScore
# 0                             Londa Lot                50
# 1                 2810 Robert C Byrd Dr                50
# 2                       Lochgelly Tract                50
# 3                            Ghent Plot                50
# 4                      203 Elizabeth Wy                50
# ..                                  ...               ...
# 187          Hinton Technology Building                50
# 188  Laurel Ridge Professional Building                50
# 189      University Drive Business Park                50
# 190                    3004 Flat Top Rd                50
# 191                      Fayette Clinic                50
#
# [192 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set a larger figure size
plt.figure(figsize=(12, 10))

sns.heatmap(df[essential_columns].isnull(), cmap='viridis', cbar=False)

plt.title('Missing Values Heatmap', fontsize=16)
plt.xlabel('Columns', fontsize=14)
plt.ylabel('Properties', fontsize=14)
plt.yticks(fontsize=10)
plt.xticks(rotation=90, fontsize=10)
plt.show()
